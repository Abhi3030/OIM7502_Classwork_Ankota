# %% [markdown]
# # Monday.com Data Extraction

# %% [markdown]
# ### Data Structure

# %%
import requests
import json
import pandas as pd

# API Key and Headers
api_key ='eyJhbGciOiJIUzI1NiJ9.eyJ0aWQiOjMwNTQ0MzI4MiwiYWFpIjoxMSwidWlkIjoyODgyNTM4MiwiaWFkIjoiMjAyMy0xMi0yOVQwODozMzoxNC4wMDBaIiwicGVyIjoibWU6d3JpdGUiLCJhY3RpZCI6MTE1MjY1MjAsInJnbiI6InVzZTEifQ.y09MV5L1iKMfyowlDKE2lhovON4WuDfI4lxcnyFq9CI'
headers = {"Authorization": api_key}
api_url = "https://api.monday.com/v2"

# Query to fetch boards and their columns
query_boards = """
{
  boards {
    id
    name
    columns {
      id
      title
      type
    }
  }
}
"""

response = requests.post(api_url, json={'query': query_boards}, headers=headers)
boards_data = response.json()['data']['boards']
boards_data
# Out:
# [{'id': '5893322376',
#   'name': 'New Board',
#   'columns': [{'id': 'name', 'title': 'Name', 'type': 'name'},
#    {'id': 'person', 'title': 'Person', 'type': 'people'},
#    {'id': 'status', 'title': 'Status', 'type': 'status'},
#    {'id': 'date4', 'title': 'Date', 'type': 'date'}]},
#  {'id': '2431678766',
#   'name': 'Subitems of Deals',
#   'columns': [{'id': 'name', 'title': 'Name', 'type': 'name'},
#    {'id': 'person', 'title': 'Owner', 'type': 'people'},
#    {'id': 'status', 'title': 'Status', 'type': 'status'},
#    {'id': 'date0', 'title': 'Date', 'type': 'date'}]},
#  {'id': '2431678613',
#   'name': 'Referred By',
#   'columns': [{'id': 'name', 'title': 'Name', 'type': 'name'},
#    {'id': 'status', 'title': 'Lead Sources', 'type': 'status'},
#    {'id': 'connect_boards3', 'title': 'Contacts', 'type': 'board_relation'},
#    {'id': 'mirror1', 'title': 'Deals', 'type': 'mirror'},
#    {'id': 'status5', 'title': 'Priority', 'type': 'status'},
#    {'id': 'mirror6', 'title': 'Email', 'type': 'mirror'},
#    {'id': 'text4', 'title': 'Comments', 'type': 'text'}]},
#  {'id': '2431678567',
#   'name': 'Contacts',
#   'columns': [{'id': 'name', 'title': 'Name', 'type': 'name'},
#    {'id': 'link_to___accounts9',
#     'title': 'Accounts',
#     'type': 'board_relation'},
#    {'id': 'link_to___deals', 'title': 'Deals', 'type': 'board_relation'},
#    {'id': 'title5', 'title': 'Relationship Type', 'type': 'dropdown'},
#    {'id': 'status5', 'title': 'Priority', 'type': 'status'},
#    {'id': 'phone', 'title': 'Phone', 'type': 'phone'},
#    {'id': 'email', 'title': 'Email', 'type': 'email'},
#    {'id': 'long_text4', 'title': 'Comments', 'type': 'long_text'}]},
#  {'id': '2431678484',
#   'name': 'Deals',
#   'columns': [{'id': 'name', 'title': 'Name', 'type': 'name'},
#    {'id': 'subitems', 'title': 'Tasks', 'type': 'subtasks'},
#    {'id': 'person', 'title': 'Sales Rep', 'type': 'people'},
#    {'id': 'connect_boards', 'title': 'Referred By', 'type': 'board_relation'},
#    {'id': 'connect_boards1', 'title': 'Contacts', 'type': 'board_relation'},
#    {'id': 'mirror8', 'title': 'Lead Sources', 'type': 'mirror'},
#    {'id': 'connect_boards0', 'title': 'Lead Source', 'type': 'board_relation'},
#    {'id': 'status', 'title': 'Stage', 'type': 'status'},
#    {'id': 'status9', 'title': 'Priority', 'type': 'status'},
#    {'id': 'numbers2', 'title': 'Weekly Hours', 'type': 'numbers'},
#    {'id': 'numbers6', 'title': 'Hourly Rate', 'type': 'numbers'},
#    {'id': 'formula9', 'title': 'Weekly Value', 'type': 'formula'},
#    {'id': 'formula0', 'title': 'Annual Value', 'type': 'formula'},
#    {'id': 'numbers0', 'title': 'Close Probability', 'type': 'numbers'},
#    {'id': 'formula5', 'title': 'Annual Forecast Value', 'type': 'formula'},
#    {'id': 'date', 'title': 'Expected Close Date', 'type': 'date'},
#    {'id': 'date9', 'title': 'Close Date', 'type': 'date'},
#    {'id': 'date1', 'title': 'Deal creation date', 'type': 'date'},
#    {'id': 'formula', 'title': 'Deal length', 'type': 'formula'},
#    {'id': 'date7', 'title': 'Follow Up Date', 'type': 'date'},
#    {'id': 'text', 'title': 'Client Address', 'type': 'text'},
#    {'id': 'date6', 'title': 'Client Date of Birth', 'type': 'date'},
#    {'id': 'text0', 'title': 'Client City', 'type': 'text'},
#    {'id': 'text9', 'title': 'Client State', 'type': 'text'},
#    {'id': 'text6', 'title': 'Client Zipcode', 'type': 'text'},
#    {'id': 'text2', 'title': 'Phone Number', 'type': 'text'},
#    {'id': 'text8', 'title': 'PatientID', 'type': 'text'}]}]

# %%
query = '''
{
  boards(limit: 5) {
    name
    id
    columns {
      id
      title
      type
      settings_str
    }
  }
}
'''

data = {'query': query}

r = requests.post(url=api_url, json=data, headers=headers)
response_json = r.json()

# Relevant data for DataFrame
boards_data = response_json['data']['boards']
columns_data = []

for board in boards_data:
    board_id = board['id']
    board_name = board['name']
    for column in board['columns']:
        columns_data.append({
            'Board ID': board_id,
            'Board Name': board_name,
            'Column ID': column['id'],
            'Column Title': column['title'],
            'Column Type': column['type'],
            'Column Settings': column['settings_str']
        })

board_details = pd.DataFrame(columns_data)

board_details
# Out:
#       Board ID         Board Name            Column ID           Column Title  \
# 0   5893322376          New Board                 name                   Name
# 1   5893322376          New Board               person                 Person
# 2   5893322376          New Board               status                 Status
# 3   5893322376          New Board                date4                   Date
# 4   2431678766  Subitems of Deals                 name                   Name
# 5   2431678766  Subitems of Deals               person                  Owner
# 6   2431678766  Subitems of Deals               status                 Status
# 7   2431678766  Subitems of Deals                date0                   Date
# 8   2431678613        Referred By                 name                   Name
# 9   2431678613        Referred By               status           Lead Sources
# 10  2431678613        Referred By      connect_boards3               Contacts
# 11  2431678613        Referred By              mirror1                  Deals
# 12  2431678613        Referred By              status5               Priority
# 13  2431678613        Referred By              mirror6                  Email
# 14  2431678613        Referred By                text4               Comments
# 15  2431678567           Contacts                 name                   Name
# 16  2431678567           Contacts  link_to___accounts9               Accounts
# 17  2431678567           Contacts      link_to___deals                  Deals
# 18  2431678567           Contacts               title5      Relationship Type
# 19  2431678567           Contacts              status5               Priority
# 20  2431678567           Contacts                phone                  Phone
# 21  2431678567           Contacts                email                  Email
# 22  2431678567           Contacts           long_text4               Comments
# 23  2431678484              Deals                 name                   Name
# 24  2431678484              Deals             subitems                  Tasks
# 25  2431678484              Deals               person              Sales Rep
# 26  2431678484              Deals       connect_boards            Referred By
# 27  2431678484              Deals      connect_boards1               Contacts
# 28  2431678484              Deals              mirror8           Lead Sources
# 29  2431678484              Deals      connect_boards0            Lead Source
# 30  2431678484              Deals               status                  Stage
# 31  2431678484              Deals              status9               Priority
# 32  2431678484              Deals             numbers2           Weekly Hours
# 33  2431678484              Deals             numbers6            Hourly Rate
# 34  2431678484              Deals             formula9           Weekly Value
# 35  2431678484              Deals             formula0           Annual Value
# 36  2431678484              Deals             numbers0      Close Probability
# 37  2431678484              Deals             formula5  Annual Forecast Value
# 38  2431678484              Deals                 date    Expected Close Date
# 39  2431678484              Deals                date9             Close Date
# 40  2431678484              Deals                date1     Deal creation date
# 41  2431678484              Deals              formula            Deal length
# 42  2431678484              Deals                date7         Follow Up Date
# 43  2431678484              Deals                 text         Client Address
# 44  2431678484              Deals                date6   Client Date of Birth
# 45  2431678484              Deals                text0            Client City
# 46  2431678484              Deals                text9           Client State
# 47  2431678484              Deals                text6         Client Zipcode
# 48  2431678484              Deals                text2           Phone Number
# 49  2431678484              Deals                text8              PatientID
#
#        Column Type                                    Column Settings
# 0             name                                                 {}
# 1           people                                                 {}
# 2           status  {"done_colors":[1],"labels":{"0":"Postponed","...
# 3             date                                                 {}
# 4             name                                                 {}
# 5           people                                                 {}
# 6           status  {"done_colors":[1],"hide_footer":true,"labels"...
# 7             date                                                 {}
# 8             name                                                 {}
# 9           status  {"done_colors":[1],"color_mapping":{"0":15,"1"...
# 10  board_relation  {"allowMultipleBoards":true,"boardIds":[243167...
# 11          mirror  {"relation_column":{"connect_boards3":true},"d...
# 12          status  {"done_colors":[1],"color_mapping":{"4":6,"6":...
# 13          mirror  {"relation_column":{"connect_boards3":true},"d...
# 14            text                                                 {}
# 15            name                                                 {}
# 16  board_relation     {"boardIds":[2431678613],"boardId":2431678613}
# 17  board_relation     {"boardIds":[2431678484],"boardId":2431678484}
# 18        dropdown  {"labels":[{"id":1,"name":"Daughter"},{"id":2,...
# 19          status  {"done_colors":[1],"color_mapping":{"4":6,"6":...
# 20           phone                                                 {}
# 21           email                                                 {}
# 22       long_text                                                 {}
# 23            name                                                 {}
# 24        subtasks  {"allowMultipleItems":true,"itemTypeName":"col...
# 25          people                                                 {}
# 26  board_relation  {"allowCreateReflectionColumn":false,"boardIds...
# 27  board_relation  {"allowCreateReflectionColumn":false,"boardIds...
# 28          mirror  {"relation_column":{"connect_boards":true},"di...
# 29  board_relation  {"allowCreateReflectionColumn":false,"boardIds...
# 30          status  {"done_colors":[1],"color_mapping":{"0":14,"2"...
# 31          status  {"done_colors":[1],"hide_footer":true,"color_m...
# 32         numbers                                                 {}
# 33         numbers  {"unit":{"symbol":"$","custom_unit":"","direct...
# 34         formula                {"formula":"{numbers2}*{numbers6}"}
# 35         formula                        {"formula":"{formula9}*50"}
# 36         numbers  {"unit":{"symbol":"%","custom_unit":"","direct...
# 37         formula                {"formula":"{formula0}*{numbers0}"}
# 38            date                              {"hide_footer":false}
# 39            date                                                 {}
# 40            date                              {"hide_footer":false}
# 41         formula  {"formula":"IF({status}=\"Won\",CONCATENATE(DA...
# 42            date                              {"hide_footer":false}
# 43            text                                                 {}
# 44            date                              {"hide_footer":false}
# 45            text                                                 {}
# 46            text                                                 {}
# 47            text                                                 {}
# 48            text                                                 {}
# 49            text                                                 {}

# %% [markdown]
# ### Board by Board

# %%
# Initializing a dictionary to hold DataFrames for each board
dfs = {}
#to fetch data from all boards
for board in boards_data:
    board_id = board['id']
    board_name = board.get('name', f"Board_{board_id}")  

    query = '''
    query {
      boards(ids: %s) {
        columns {
          id
          title
        }
        items_page(limit: 20) {
          items {
            id
            name
            column_values {
              id
              text
              value
            }
          }
        }
      }
    }
    ''' % board_id

    response = requests.post(api_url, json={'query': query}, headers=headers)

    if response.status_code == 200:
        board_info = response.json()['data']['boards'][0]
        data = board_info['items_page']['items']
        columns_info = board_info['columns']

        # mapping from column ID to column title
        columns_mapping = {column['id']: column['title'] for column in columns_info}

        # Replace unique_columns with column titles instead of IDs
        unique_columns = set(columns_mapping.values())  # Using set to avoid duplicates

        # DataFrame columns with 'Item ID' and 'Item Name' always present
        df_columns = ['Item ID', 'Item Name'] + sorted(unique_columns)

        column_values_data = []

        for item in data:
            row_data = {'Item ID': item['id'], 'Item Name': item['name']}
            for column_value in item['column_values']:
                column_title = columns_mapping.get(column_value['id'], 'Unknown Column')
                # Attempt to parse 'value' as JSON and extract a meaningful display string, if 'text' is not available
                if column_value['text']:
                    row_data[column_title] = column_value['text']
                else:
                    try:
                        value_parsed = json.loads(column_value['value']) if column_value['value'] else None
                        if isinstance(value_parsed, dict) and 'text' in value_parsed:
                            row_data[column_title] = value_parsed['text']
                        else:
                            row_data[column_title] = str(value_parsed)
                    except json.JSONDecodeError:
                        row_data[column_title] = column_value['value']
            column_values_data.append(row_data)

        # DataFrame from the populated data
        df_final = pd.DataFrame(column_values_data, columns=['Item ID', 'Item Name'] + sorted(unique_columns))
        dfs[board_name] = df_final  # Storing the DataFrame in the dictionary using the board name as the key

    else:
        print(f"Failed to fetch data for board ID {board_id}: HTTP Status Code {response.status_code}")

# %%
dfs['Deals']
# Out:
#        Item ID       Item Name Annual Forecast Value Annual Value  \
# 0   2431679009    Dorothy Mall                  None         None
# 1   2497616794        Anna Bon                  None         None
# 2   2497621949  Viktor Shmidke                  None         None
# 3   4651022562       Sam Brown                  None         None
# 4   5847525269     Carmen Popa                  None         None
# 5   5863619357     Rana Zubair                  None         None
# 6   5892131929     Anna Tester                  None         None
# 7   2431678988     Maria Green                  None         None
# 8   2432241000       Kyle Solo                  None         None
# 9   2485825874    Will Masulla                  None         None
# 10  2431679024   Anton Zaytzev                  None         None
# 11  2495728334  Marissa Lumber                  None         None
# 12  2431678973    Lolita Smith                  None         None
# 13  2495719092      Kate Smith                  None         None
#
#                          Client Address Client City Client Date of Birth  \
# 0                123 Test St, MA, 02067        None           1978-11-10
# 1                123 Test St, MA, 02067        None           1990-02-15
# 2                123 Test St, MA, 02067        None           1965-10-08
# 3   House 16, Street 125, Jinnah Garden        None           1979-05-30
# 4                                  None        None           1995-01-31
# 5   House 16, Street 125, Jinnah Garden   Islamabad           1996-05-18
# 6                                  None        None                 None
# 7                                  None        None                 None
# 8                                  None        None                 None
# 9                                  None        None                 None
# 10                                 None        None                 None
# 11                                 None        None                 None
# 12                                 None        None                 None
# 13                                 None        None                 None
#
#        Client State Client Zipcode  Close Date  ... Name PatientID  \
# 0              None          02110        None  ...  NaN      8813
# 1              None          44000        None  ...  NaN      8814
# 2              None           None        None  ...  NaN      8815
# 3              None           None        None  ...  NaN      8816
# 4              None          02110        None  ...  NaN      8817
# 5   Federal Capital          02882        None  ...  NaN      8812
# 6              None           None        None  ...  NaN      None
# 7              None           None        None  ...  NaN      None
# 8              None           None        None  ...  NaN      None
# 9              None           None        None  ...  NaN      None
# 10             None           None  2022-02-02  ...  NaN      None
# 11             None           None        None  ...  NaN      None
# 12             None           None  2022-04-01  ...  NaN      None
# 13             None           None        None  ...  NaN      None
#
#    Phone Number Priority                                        Referred By  \
# 0    7813301775     High  {'changed_at': '2022-04-01T15:34:04.823Z', 'li...
# 1    3345253666   Medium  {'changed_at': '2022-04-01T19:18:47.387Z', 'li...
# 2    3345253666   Medium  {'changed_at': '2024-01-05T17:55:14.883Z', 'li...
# 3    3345253666     None  {'changed_at': '2024-01-12T16:37:14.243Z', 'li...
# 4          None     None                                                 {}
# 5    7813301775     None  {'changed_at': '2024-01-19T17:55:13.833Z', 'li...
# 6          None     None  {'changed_at': '2024-01-19T17:53:55.828Z', 'li...
# 7          None     High  {'changed_at': '2022-04-01T17:19:29.046Z', 'li...
# 8          None     None  {'changed_at': '2022-04-01T17:22:56.659Z', 'li...
# 9          None     None  {'changed_at': '2022-04-01T18:55:05.842Z', 'li...
# 10         None      Low  {'changed_at': '2022-04-01T18:55:12.487Z', 'li...
# 11         None     None  {'changed_at': '2022-04-01T18:55:47.301Z', 'li...
# 12         None     High  {'changed_at': '2022-04-01T15:34:23.661Z', 'li...
# 13         None     None  {'changed_at': '2022-04-01T18:56:03.507Z', 'li...
#
#       Sales Rep       Stage Tasks Weekly Hours  Weekly Value
# 0   Ken Accardi     Inquiry    {}           60          None
# 1          None     Inquiry    {}           50          None
# 2          None     Inquiry    {}           55          None
# 3          None     Inquiry    {}         None          None
# 4          None     Inquiry    {}         None          None
# 5          None  Assessment    {}         None          None
# 6          None     Inquiry    {}         None          None
# 7   Ken Accardi         Won    {}           40          None
# 8   Ken Accardi         Won    {}           40          None
# 9   Ken Accardi   Postponed    {}           56          None
# 10  Ken Accardi   Postponed    {}           40          None
# 11         None   Postponed    {}           50          None
# 12  Ken Accardi   Postponed    {}           55          None
# 13         None        Lost    {}           30          None
#
# [14 rows x 29 columns]

# %%
# To CSV
dfs['Deals'].to_csv('monday_deals.csv', index=False)

# %%
dfs['New Board']
# Out:
#       Item ID Item Name        Date  Name Person  \
# 0  5893322473    Item 1  2024-01-18   NaN   None
# 1  5893322501    Item 2  2024-01-21   NaN   None
# 2  5893322523    Item 3  2024-01-20   NaN   None
# 3  5893322565    Item 4  2024-01-18   NaN   None
# 4  5893322540    Item 5  2024-01-21   NaN   None
#
#                                               Status
# 0                                          Postponed
# 1                                         Closed Won
# 2  {'index': 5, 'post_id': None, 'changed_at': '2...
# 3                                               None
# 4                                               None

# %%
# To CSV
dfs['New Board'].to_csv('monday_new_board.csv', index=False)

# %%
dfs['Subitems of Deals']
# Out:
# Empty DataFrame
# Columns: [Item ID, Item Name, Date, Name, Owner, Status]
# Index: []

# %%
# To CSV
dfs['Subitems of Deals'].to_csv('monday_subitemsdeals.csv', index=False)

# %%
dfs['Referred By']
# Out:
#       Item ID               Item Name Comments  \
# 0  2431678922                     MGH     None
# 1  2431678956             Maria Louis     None
# 2  2496490817  Canton Jewish Services     None
# 3  2496994886       Veterans Hospital     None
# 4  5847497218                    Sara     None
# 5  5847609504              Carmen Org     None
# 6  6090899076           Joseph Zubair     None
#
#                                             Contacts Deals Email  \
# 0  {'changed_at': '2024-01-05T17:54:25.592Z', 'li...  None  None
# 1  {'changed_at': '2024-01-12T16:32:42.273Z', 'li...  None  None
# 2  {'changed_at': '2022-04-01T18:55:52.267Z', 'li...  None  None
# 3  {'changed_at': '2022-04-01T17:22:44.918Z', 'li...  None  None
# 4  {'changed_at': '2024-01-12T16:40:05.066Z', 'li...  None  None
# 5         {'changed_at': '2024-01-12T16:51:14.184Z'}  None  None
# 6  {'linkedPulseIds': [{'linkedPulseId': 58636222...  None  None
#
#                                         Lead Sources  Name Priority
# 0                                           Industry   NaN     High
# 1     Governments - Veterans Administration Programs   NaN      Low
# 2  Healthcare Professionals  - Skilled Nursing Fa...   NaN     None
# 3                                   Veterans Affairs   NaN     None
# 4                                               None   NaN     None
# 5                                           Industry   NaN     None
# 6                                               None   NaN     None

# %%
# To CSV
dfs['Referred By'].to_csv('monday_referredby.csv', index=False)

# %%
dfs['Contacts']
# Out:
#        Item ID       Item Name  \
# 0   5847484730      Sara Moore
# 1   2467119845  Ariana Willson
# 2   2431678983    Phoenix Levy
# 3   2431678968     Maria Louis
# 4   2431678992  Leilani Krause
# 5   2438011396      John Green
# 6   2496989486      Alla Bezos
# 7   2496998845     Bob Candiev
# 8   2497629156  Anastasia Snow
# 9   5757361602             Ken
# 10  5847521398        Leo Test
# 11  5863622226      RZ Contact
#
#                                              Accounts       Comments  \
# 0   {'changed_at': '2024-01-12T16:37:19.851Z', 'li...           None
# 1   {'changed_at': '2022-04-01T17:11:51.690Z', 'li...           None
# 2   {'changed_at': '2022-04-01T17:11:58.519Z', 'li...           None
# 3                                                  {}           None
# 4                                                  {}           None
# 5                                                  {}           None
# 6                                                  {}           None
# 7   {'linkedPulseIds': [{'linkedPulseId': 24969948...           None
# 8   {'linkedPulseIds': [{'linkedPulseId': 24316789...           None
# 9                                                  {}           None
# 10  {'linkedPulseIds': [{'linkedPulseId': 58474972...           None
# 11  {'changed_at': '2024-02-19T14:44:58.168Z', 'li...  sadsa\nabcdef
#
#                                                 Deals  \
# 0   {'changed_at': '2024-01-12T16:37:49.715Z', 'li...
# 1                                                  {}
# 2   {'linkedPulseIds': [{'linkedPulseId': 24316790...
# 3   {'changed_at': '2022-04-01T19:19:34.577Z', 'li...
# 4   {'changed_at': '2022-04-01T15:53:32.702Z', 'li...
# 5   {'linkedPulseIds': [{'linkedPulseId': 24316789...
# 6   {'changed_at': '2022-04-01T19:17:54.369Z', 'li...
# 7                                                  {}
# 8                                                  {}
# 9                                                  {}
# 10  {'changed_at': '2024-01-12T16:51:19.702Z', 'li...
# 11  {'changed_at': '2024-01-16T08:24:45.864Z', 'li...
#
#                         Email  Name         Phone Priority Relationship Type
# 0                        None   NaN          None     None              None
# 1                        None   NaN          None     None              None
# 2           Phoenix@email.com   NaN   13254785698     High       {'ids': []}
# 3           Madison@email.com   NaN   18547220499     High            Sister
# 4           Leilani@email.com   NaN   13125632541   Medium          Daughter
# 5                        None   NaN          None     None              None
# 6                        None   NaN          None     None              None
# 7                        None   NaN          None     None              None
# 8                        None   NaN          None     None              None
# 9                        None   NaN          None     None              None
# 10                       None   NaN          None     None              None
# 11  joseph.zubair@redcoast.co   NaN  923315559583   Medium               Son

# %%
# To CSV
dfs['Contacts'].to_csv('monday_contacts.csv', index=False)

# %% [markdown]
# ### Data Management

# %%
import pandas as pd
import numpy as np

df_deals = dfs['Deals']

df_deals['Weekly Hours'] = pd.to_numeric(df_deals['Weekly Hours'], errors='coerce').fillna(0)

average_hours_by_stage = df_deals.groupby('Stage')['Weekly Hours'].mean()

print("\nAverage Weekly Hours by Stage:\n", average_hours_by_stage)

if 'Exit Date' in df_deals.columns and 'Reason for Leaving' in df_deals.columns:
    pass
# Out:
# Average Weekly Hours by Stage:
#  Stage
# Assessment     0.00
# Inquiry       27.50
# Lost          30.00
# Postponed     50.25
# Won           40.00
# Name: Weekly Hours, dtype: float64
